# %%
from os import name
#proc = running processes are stored here#
#procdump = iterate every process and prints#
#each process is stored in struct
#Pro() - running (all Process)

#xv6 is the first process is init (userinit) ---> init--(kfork)--> here kfork() is fork()then sh--.us2

my_cpu() --> #cpu struct return
my_proc()--> #return the running process

-> name
-> pid
-> page-table -> lock

how to enter xv6 make qemu
how ro exit  ctrl A then x

gt stash dile aber ager jaigay ferot jabo

git diff > samiul.patch it will help to see how many changes i have made over there. eta dekta help korbe
